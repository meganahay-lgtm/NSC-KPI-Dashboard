# %%
import pandas as pd

# %%
df = pd.read_excel("../data/nationwide_supply_asset_list.xlsx")
df.head()
# Out:
#   Store #             Store Name    Street Address      Suburb State  \
# 0  NSW001  Nationwide Parramatta      392 Wharf Rd  Parramatta   NSW
# 1  NSW002   Nationwide Chatswood  448 Commerce Way   Chatswood   NSW
# 2  NSW003     Nationwide Penrith  220 Elizabeth St     Penrith   NSW
# 3  NSW003     Nationwide Penrith  220 Elizabeth St     Penrith   NSW
# 4  NSW004   Nationwide Liverpool   271 Victoria Rd   Liverpool   NSW
#
#    Postcode  Phone Number                        Asset Make/Model  \
# 0      2660  02 8683 7708   Baler - Kestrel Waste Systems BL-4000
# 1      2200  02 7520 1920   Baler - Kestrel Waste Systems BL-6500
# 2      2871  02 8393 1591   Baler - Kestrel Waste Systems BL-6500
# 3      2871  02 8393 1591  Compactor - Ironbark Compaction CP-800
# 4      2206  02 4890 9098   Baler - Kestrel Waste Systems BL-6500
#
#   Serial Number Installation Date  ...       May  Jun       Jul       Aug  \
# 0      SN100003        2015-12-10  ...       NaN  NaN  6monthly       NaN
# ...
